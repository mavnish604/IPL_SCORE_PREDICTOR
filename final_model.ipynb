# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("final_scores.csv")

# %%
df
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   0.1
# 1         335982             M Chinnaswamy Stadium        1   0.2
# 2         335982             M Chinnaswamy Stadium        1   0.3
# 3         335982             M Chinnaswamy Stadium        1   0.4
# 4         335982             M Chinnaswamy Stadium        1   0.5
# ...          ...                               ...      ...   ...
# 243810   1370353  Narendra Modi Stadium, Ahmedabad        2  14.2
# 243811   1370353  Narendra Modi Stadium, Ahmedabad        2  14.3
# 243812   1370353  Narendra Modi Stadium, Ahmedabad        2  14.4
# 243813   1370353  Narendra Modi Stadium, Ahmedabad        2  14.5
# 243814   1370353  Narendra Modi Stadium, Ahmedabad        2  14.6
#
#                  batting_team                 bowling_team  wickets_remaining  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore                 10
# ...

# %%
df["score"]=0
df["runs_scored"] = df["runs_scored"].astype(float)
final_scores = df.groupby(["match_id", "batting_team"])["runs_scored"].sum().reset_index()
final_scores.rename(columns={"runs_scored": "final_score"}, inplace=True)
df = df.merge(final_scores, on=["match_id", "batting_team"], how="left")
df
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   0.1
# 1         335982             M Chinnaswamy Stadium        1   0.2
# 2         335982             M Chinnaswamy Stadium        1   0.3
# 3         335982             M Chinnaswamy Stadium        1   0.4
# 4         335982             M Chinnaswamy Stadium        1   0.5
# ...          ...                               ...      ...   ...
# 243810   1370353  Narendra Modi Stadium, Ahmedabad        2  14.2
# 243811   1370353  Narendra Modi Stadium, Ahmedabad        2  14.3
# 243812   1370353  Narendra Modi Stadium, Ahmedabad        2  14.4
# 243813   1370353  Narendra Modi Stadium, Ahmedabad        2  14.5
# 243814   1370353  Narendra Modi Stadium, Ahmedabad        2  14.6
#
#                  batting_team                 bowling_team  wickets_remaining  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore                 10
# ...

# %%
def update_running_score(df):
    df["score"] = 0 
    for (match, innings), group in df.groupby(["match_id", "innings"]):
        total_score = 0 
        for idx in group.index:
            total_score += df.at[idx, "runs_scored"]
            df.at[idx, "score"] = total_score  

    return df

# %%
df = update_running_score(df)

# %%
df
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   0.1
# 1         335982             M Chinnaswamy Stadium        1   0.2
# 2         335982             M Chinnaswamy Stadium        1   0.3
# 3         335982             M Chinnaswamy Stadium        1   0.4
# 4         335982             M Chinnaswamy Stadium        1   0.5
# ...          ...                               ...      ...   ...
# 243810   1370353  Narendra Modi Stadium, Ahmedabad        2  14.2
# 243811   1370353  Narendra Modi Stadium, Ahmedabad        2  14.3
# 243812   1370353  Narendra Modi Stadium, Ahmedabad        2  14.4
# 243813   1370353  Narendra Modi Stadium, Ahmedabad        2  14.5
# 243814   1370353  Narendra Modi Stadium, Ahmedabad        2  14.6
#
#                  batting_team                 bowling_team  wickets_remaining  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore                 10
# ...

# %%
df["runs_last_5_overs"] = (
    df.groupby(["match_id", "innings"])["runs_scored"]
    .rolling(window=30, min_periods=1)
    .sum()
    .reset_index(level=[0, 1], drop=True)
)
df = df[df["ball"] >= 5.0].reset_index(drop=True)

# %%
df
# Out:
#         match_id                             venue  innings  ball  \
# 0         335982             M Chinnaswamy Stadium        1   5.1
# 1         335982             M Chinnaswamy Stadium        1   5.2
# 2         335982             M Chinnaswamy Stadium        1   5.3
# 3         335982             M Chinnaswamy Stadium        1   5.4
# 4         335982             M Chinnaswamy Stadium        1   5.5
# ...          ...                               ...      ...   ...
# 179852   1370353  Narendra Modi Stadium, Ahmedabad        2  14.2
# 179853   1370353  Narendra Modi Stadium, Ahmedabad        2  14.3
# 179854   1370353  Narendra Modi Stadium, Ahmedabad        2  14.4
# 179855   1370353  Narendra Modi Stadium, Ahmedabad        2  14.5
# 179856   1370353  Narendra Modi Stadium, Ahmedabad        2  14.6
#
#                  batting_team                 bowling_team  wickets_remaining  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore                 10
# ...

# %%
df["balls_bowled"] = (df["ball"].astype(int) * 6) + ((df["ball"] % 1) * 10)

# Calculate remaining balls
df["balls_remaining"] = 120 - df["balls_bowled"]

# %%
df=df.drop(columns=["balls_bowled","ball","match_id"])

# %%
df
# Out:
#                                    venue  innings           batting_team  \
# 0                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 1                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 2                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 3                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 4                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# ...                                  ...      ...                    ...
# 179852  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179853  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179854  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179855  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179856  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
#
#                        bowling_team  wickets_remaining  runs_scored  score  \
# ...

# %%
df.dropna(inplace=True)

# %%
df=df.drop(columns=["runs_scored"])

# %%
df
# Out:
#                                    venue  innings           batting_team  \
# 0                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 1                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 2                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 3                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 4                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# ...                                  ...      ...                    ...
# 179852  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179853  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179854  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179855  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179856  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
#
#                        bowling_team  wickets_remaining  score  final_score  \
# ...

# %%
df.dropna(inplace=True)

# %%
df['overs_played'] = (120 - df['balls_remaining']) / 6
df['crr'] = df['score'] / df['overs_played']
df=df.drop(columns=["overs_played"])
df
# Out:
#                                    venue  innings           batting_team  \
# 0                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 1                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 2                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 3                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# 4                  M Chinnaswamy Stadium        1  Kolkata Knight Riders
# ...                                  ...      ...                    ...
# 179852  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179853  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179854  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179855  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
# 179856  Narendra Modi Stadium, Ahmedabad        2    Chennai Super Kings
#
#                        bowling_team  wickets_remaining  score  final_score  \
# ...

# %%
df["balls_remaining"] = df["balls_remaining"].apply(lambda x: 0 if np.abs(x) < 1e-10 else int(x))
final_df = df.sample(df.shape[0])

# %%
from sklearn.model_selection import train_test_split
X=final_df.drop(columns=['final_score'])
y= final_df['final_score']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
cltrf = ColumnTransformer([
    ('cltrf',OneHotEncoder(sparse_output=False,drop='first'),["batting_team","bowling_team","venue"])
]
,remainder="passthrough")

# %%
model2 = Pipeline(steps=[
    ('step1',cltrf),
    ('step2',StandardScaler()),
    ("step3",XGBRegressor(n_estimators=1500,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
model2.fit(X_train,y_train)
# Out:
# C:\Users\mavni\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cltrf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
# ...

# %%
y_pred = model2.predict(X_test)

# %%
print("r2 score: ",r2_score(y_test,y_pred))
print("MEAN ABSOLUTE ERROR: ",mean_absolute_error(y_test,y_pred))
# Out:
# r2 score:  0.9770505825824108
# MEAN ABSOLUTE ERROR:  2.653276462887917

# %%
import pickle as pkl

# %%
pkl.dump(model2,open("model2.pkl","wb"))

# %%
batting_teams = final_df["batting_team"].unique().tolist()
bowling_teams = final_df["bowling_team"].unique().tolist()
stadiums = df["venue"].unique().tolist()

# Combine batting and bowling teams to get a unique list of teams
teams = list(set(batting_teams + bowling_teams))

# Print results
print("Teams:", teams)
print("Stadiums:", stadiums)
# Out:
# Teams: ['Lucknow Super Giants', 'Rising Pune Supergiants', 'Punjab Kings', 'Pune Warriors', 'Kolkata Knight Riders', 'Mumbai Indians', 'Gujarat Lions', 'Kings XI Punjab', 'Delhi Capitals', 'Rising Pune Supergiant', 'Chennai Super Kings', 'Kochi Tuskers Kerala', 'Royal Challengers Bangalore', 'Gujarat Titans', 'Sunrisers Hyderabad', 'Delhi Daredevils', 'Deccan Chargers', 'Rajasthan Royals']
# ...
